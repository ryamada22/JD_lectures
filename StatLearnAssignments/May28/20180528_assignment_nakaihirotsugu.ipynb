# %% [markdown]
# ## Assignment①
# $y = \beta_1x_1 + \beta_2 x_2$ is a plane in 3d space where $x_1, x_2, y$ are three axes.<br> Draw the plane with $(\beta_1, \beta_2) = (2,-1)$ in 3d space.

# %%
x1 <- seq(-10, 10, 0.1)
x2 <- seq(-10, 10, 0.1)
f <- function(x1,x2){2*x1-x2}
y <- outer(x1, x2, f)
persp(x1,x2,y,main="y=2(x1)-x2",theta=30,phi=10,ticktype = "detailed") #関数persp
# Out:
# Plot with title “y=2(x1)-x2”

# %% [markdown]
# ## Assignment②
# $||y-X \beta ||^2$ is a function of $\beta$ when y and X are given. When $$ y = \begin{pmatrix} 1\\ 2\\ 3\\ 4 \end{pmatrix}$$ and $$X = \begin {pmatrix} 0,0\\ 1,0 \\ 0,1 \\ 1,1 \end{pmatrix},$$ draw a curved surface over grid points of $(\beta_1, \beta_2)$.<br><br><br>

# %% [markdown]
# Rできれいなcodeの書き方が分からなかったので、、<br>
#  $$y-Xβ = \begin {pmatrix} 1\\ 2 \\ 3 \\ 4 \end{pmatrix}-\begin{pmatrix} 0,0\\ 1,0 \\ 0,1 \\ 1,1 \end{pmatrix}\begin {pmatrix} \beta1\\ \beta2\end{pmatrix}$$=$$\begin {pmatrix} 1\\ 2-\beta1 \\ 3-\beta2 \\ 4-(\beta1+\beta2) \end{pmatrix}$$
#
# $||y-X \beta ||^2$ = 30-12$\beta1$+2$\beta2$+2$\beta1^2$+2$\beta2^2$-2$\beta1$$\beta2$

# %%
b1 <- seq(-10, 10, 0.1)
b2 <- seq(-10, 10, 0.1)
f <- function(b1,b2){30-12*b1+2*b2+2*(b1^2)+2*(b2^2)-2*b1*b2}
y <- outer(b1, b2, f)
persp(b1,b2,y,main="value of cost function(y)",theta=30,phi=10,ticktype = "detailed")
# Out:
# Plot with title “value of cost function(y)”

# %% [markdown]
# ## Assignment③
# $y = \beta_1 x_1 + \beta_2 x_2$ can be written as $$y = \beta_1 h_1(x) + \beta_2 h_2(x),$$ where $(h_1(x),h_2(x)) = (x_1,x_2).$ It represented a plane in 3d space $(x_1,x_2,y)$ and a point in 2d space $(\beta_1,\beta_2)$. When $$(h_1(x),h_2(x)) = (x_1+x_2,x_1^2),$$$y = \beta_1 h_1(x) + \beta_2 h_2(x)$ is not a plane in 3d space but is a point in 2d space. Draw a curved surfacef in 3d space where $x_1, x_2, y$ are three axes.

# %%
y <- matrix(c(1,2,3,4),4,1)
X <- matrix(c(0,1,0,1,0,0,1,1),4,2)
x1 <- X[1,]
x2 <- X[2,]
x3 <- X[3,]
x4 <- X[4,]
b1 <- seq(-10, 10, 0.1)
b2 <- seq(-10, 10, 0.1)

# %% [markdown]
# I'm not sure how to write a programm
