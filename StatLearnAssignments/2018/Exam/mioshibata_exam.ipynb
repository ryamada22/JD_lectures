# %% [markdown]
# # Exam of Stat Learn
# - Mio Shibata

# %% [markdown]
#  The recent topics taken up in TV programs, newspaper and magazines always include “Machine Learning”, as if it can tell the truth from data. Before taking this class, I am also one of them who tends to think that machine learning gives us a solution that can be useful in ambiguous fields, like medicine and biology. However, machine learning is just one tool to analyze the data set. Through reading the paper given for the exam, I recognized that we have to keep in mind good data handling, respective features of each　algorithm of machine learning and the way of development of my skills. And I need to learn mathematics and the algorithm more to use the machine learning in the future.

# %% [markdown]
#  The good results are come from good data handling. In Tip 1, all data sets we can attain needs good quality otherwise we lose the good result. I thought if I use some application of machine learning, we get reasonable and great result that nobody have found before. Moreover Tip 2 in the paper described three steps that should be separated from our dataset. Then we can avoid to be hallucinated. If I didn't take this class, I doubt why our datasets should be split. I learned the reason why split is important from the lectures of variance and bias. First of all I didn’t know the variance meaning at all. So, if we put the data without any handling, the variance becomes high and we may lose the important inclination from the results. In other words, God only knows the truth and what we can only do is just interpreting the result from the "good quality" dataset.

# %%
print(__doc__)

# Author: Mathieu Blondel
#         Jake Vanderplas
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline


def f(x):
    """ function to approximate by polynomial interpolation"""
    return x * np.sin(x)


# generate points used to plot
x_plot = np.linspace(0, 10, 100)

# generate points and keep a subset of them
x = np.linspace(0, 10, 100)
rng = np.random.RandomState(0)
rng.shuffle(x)
x = np.sort(x[:20])
y = f(x)

# create matrix versions of these arrays
X = x[:, np.newaxis]
X_plot = x_plot[:, np.newaxis]

colors = ['teal', 'yellowgreen', 'gold']
lw = 2
plt.plot(x_plot, f(x_plot), color='cornflowerblue', linewidth=lw,
         label="ground truth")
plt.scatter(x, y, color='navy', s=30, marker='o', label="training points")

for count, degree in enumerate([3, 4, 5]):
    model = make_pipeline(PolynomialFeatures(degree), Ridge())
    model.fit(X, y)
    y_plot = model.predict(X_plot)
    plt.plot(x_plot, y_plot, color=colors[count], linewidth=lw,
             label="degree %d" % degree)

plt.legend(loc='lower left')

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
print(__doc__)

# Author: Mathieu Blondel
#         Jake Vanderplas
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline


def f(x):
    """ function to approximate by polynomial interpolation"""
    return x * np.sin(x)


# generate points used to plot
x_plot = np.linspace(0, 10, 100)

# generate points and keep a subset of them
x = np.linspace(0, 10, 100)
rng = np.random.RandomState(0)
rng.shuffle(x)
x = np.sort(x[:20])
y = f(x)

# create matrix versions of these arrays
X = x[:, np.newaxis]
X_plot = x_plot[:, np.newaxis]

colors = ['teal', 'yellowgreen', 'gold']
lw = 2
plt.plot(x_plot, f(x_plot), color='cornflowerblue', linewidth=lw,
         label="ground truth")
plt.scatter(x, y, color='navy', s=30, marker='o', label="training points")

for count, degree in enumerate([5, 10, 19]):
    model = make_pipeline(PolynomialFeatures(degree), Ridge())
    model.fit(X, y)
    y_plot = model.predict(X_plot)
    plt.plot(x_plot, y_plot, color=colors[count], linewidth=lw,
             label="degree %d" % degree)

plt.legend(loc='lower left')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# /Users/mioshibata/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 7.445786195482991e-21 / 1.1102230246251565e-16
#   RuntimeWarning)

# %% [markdown]
#  The features of machine learning is extensive. I had heard that there are many kinds of machine learning that we can use before this class started. But I didn't pay too much attention for that each machine learning method has their characters. For example, k-nearest neighbors is good at classification but it cannot be used us regression. Before the class, I didn't distinguish the difference between regression and classification. When I heard those words, I was confused. Now when I read the Tip3, I understand that we should apply our data to an appropriate algorithm that fits our approach. I should follow some simple algorithms to learn what kinds of results are generated with some parameters. As Tip4 said, if beginners use the complicated machine learning, they may loose the point that makes the results differ from each other with respective parameters. We did play some machine learning scripts, such as Polynomial interpolation, with one parameter and it was easy for me to understand how the parameter affects the result. So Tip 4 is very reasonable for me.

# %% [markdown]
#  We can ask for help to develop our skills if we use good environment of analysis and community. I have already come to use open source programming and the community sites that were introduced at the paper on Tip 9 to 10. Such communities would definitely bring the development compared to the commercial or restricted tools because all users' abilities are connected like a graph theory. I was surprised to find that topic on the paper and these communities helped me do my assignments. So I recognized again how these communities are important for us through the assignments.

# %% [markdown]
#  Through this class I leaned basic knowledge of the machine learning and what I leaned is just the concept. I understand the abstract of each topics in the paper. But Tip 5 to 8 are very difficult for me to understand precisely, because the topics come from mathematics and the fields of algorithm. The next step for me is to understand those machine learning as the basis of mathematics of algorithm, not overview.
