# %%
from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# ...
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# scatter plotの色分けは出なかった。。

# %%
from sklearn import tree
X = [[0, 0], [2, 2]]
y = [0.5, 2.5]
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X, y)
clf.predict([[1, 1]])
# Out:
# array([0.5])

# %%
print(__doc__)

# Import the necessary modules and libraries
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(200 * rng.rand(100, 1) - 100, axis=0)
y = np.array([np.pi * np.sin(X).ravel(), np.pi * np.cos(X).ravel()]).T
y[::5, :] += (0.5 - rng.rand(20, 2))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_3 = DecisionTreeRegressor(max_depth=8)
regr_1.fit(X, y)
regr_2.fit(X, y)
regr_3.fit(X, y)

# Predict
X_test = np.arange(-100.0, 100.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)
y_3 = regr_3.predict(X_test)

# Plot the results
plt.figure()
s = 25
plt.scatter(y[:, 0], y[:, 1], c="navy", s=s,
            edgecolor="black", label="data")
plt.scatter(y_1[:, 0], y_1[:, 1], c="cornflowerblue", s=s,
            edgecolor="black", label="max_depth=2")
plt.scatter(y_2[:, 0], y_2[:, 1], c="red", s=s,
            edgecolor="black", label="max_depth=5")
plt.scatter(y_3[:, 0], y_3[:, 1], c="orange", s=s,
            edgecolor="black", label="max_depth=8")
plt.xlim([-6, 6])
plt.ylim([-6, 6])
plt.xlabel("target 1")
plt.ylabel("target 2")
plt.title("Multi-output Decision Tree Regression")
plt.legend(loc="best")
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
import numpy as np
import numpy.random as rd
import scipy.stats as st
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## データセット作り

# %% [markdown]
# ##### 作戦
# N=100 くらいが目視の限界かと思うのでそんなもんにしておく
# - 連続変数
#   - age:正規分布
#   - Na:正規分布
#   - K:正規分布
# - カテゴリ変数
#   - sex:男・女
#   - BP:high,low,normal
#   - drug:X,Y,C
# - その他
#   - chol:右に裾のの分布(対数正規分布など)
# lognormal([mean, sigma, size])

# %%
#0-5未満で１０個取り出す
x = rd.randint(low=0, high=2, size=1000)
print (x)
#xのリストに相当するlabelを記載する
li = np.array([u"男性", u"女性"])

for l in li[x]:
    print (l)
#自力ではできなかったのでしばらく調べる。
# Out:
#   File "<ipython-input-13-d3b6110610af>", line 6
#     gender <-
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# はじめにみたどんな感じにできるかがわかるHP
# https://pythondatascience.plavox.info/pandas/pandasでデータフレームを作ってみよう
# pandasでのデータセットの細かい設定の仕方
# https://stats.biopapyrus.jp/python/dataframe.html
# 次元ごとに
# https://helve-python.hatenablog.jp/entry/2017/10/29/184950

# %%
l = list['high','low','normal']
print(random.choice(l, k=30, weights=[3,1,9]))
#これだとうまくいかない
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8895ca8b83ac> in <module>()
# ----> 1 l = list['high','low','normal']
#       2 print(random.choice(l, k=30, weights=[3,1,9]))
#
# TypeError: 'type' object is not subscriptable

# %%
a = np.array(['high', 'low', 'normal'])
#bp = 
np.random.choice(a, 10, replace=True,p= [0.3,0.1, 0.6])
#, dtype='<U6' がよくわからないがうまくいったので、押し切る
#http://www.kamishima.net/mlmpyja/nbayes1/ndarray.html
# Out:
# array(['normal', 'normal', 'high', 'high', 'normal', 'normal', 'normal',
#        'normal', 'high', 'normal'], dtype='<U6')

# %%
a = np.array(['high', 'low', 'normal'])
bp = np.random.choice(a, 100, replace=True,p= [0.3,0.1,0.6])
b = np.array(['X', 'Y', 'C'])
drug = np.random.choice(b, 100, replace=True)
c = np.array(['M', 'F'])
sex = np.random.choice(c, 100, replace=True)

# %%
#年齢の作成：平均60歳　標準誤差5歳とした正規分布
age_0 = np.random.normal(60, 5, 1000)
# もしくは40−90歳のうちから1000こ
age = np.random.randint(40, 90, 100)

# %%
na = 130 + 5*np.random.normal(0,1,100)
k = 4.5 + np.random.normal(0,1,100)

# %%
mu, sigma = 3., 1. # mean and standard deviation
chol = 130 + np.random.lognormal(mu, sigma, 100)

# %%
df = pd.DataFrame({ 'Age' : age,
                    'Sex' : sex,
                    'systolic Blood Pressure' : bp,
                    'Na' : na,
                    'K' : k,
                    'T-chol' : chol, 
                    'Drug':drug
                  })

# %%
df#できた。疲れた。
# Out:
#     Age Drug         K          Na Sex      T-chol systolic Blood Pressure
# 0    77    C  4.608983  131.818133   M  139.876673                  normal
# 1    58    X  4.580057  133.660408   M  236.918267                    high
# 2    56    C  5.702470  124.955114   M  139.030526                  normal
# 3    65    X  5.756337  129.005339   M  137.560629                  normal
# 4    74    X  4.526794  127.018348   M  185.934757                    high
# 5    50    X  5.608442  130.883334   F  143.666389                    high
# 6    50    C  4.111595  121.341186   F  168.993137                  normal
# 7    64    C  4.240182  127.285358   M  139.319158                  normal
# 8    62    C  3.578608  124.167652   F  255.492755                  normal
# 9    81    X  2.292275  123.683613   F  144.935129                  normal
# 10   75    Y  5.377657  133.871925   M  255.377502                  normal
# ...

# %% [markdown]
# ### 以下参考例(上記HP以外も含めてメモ)

# %%
df = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' })
df

# %%
import numpy as np
import pandas as pd
a = np.random.randint(1, 100, (3, 2))
frame = pd.DataFrame(a, columns=["a", "b"])
print(frame)
#     a   b
# 0  85  80
# 1  85  10
# 2  17  38

# %%
list_data = [1, 2, 3]  # リスト型データ
Idx  = ["a", "b", "c"] # ラベル

pd.Series(np.array(list_data), index=Idx) # NumPy配列からSeriesを作成

# %%
data = {'col1' : [1, 2, 3], 'col2' : [10, 20, 30]}
df = pd.DataFrame(data)
print(df)
 
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30

# %%
import numpy as np
mu = 0
sigma = 1
size = 36
# locは平均、scaleは標準偏差、sizeは返す配列の形。
normals = 5 + np.random.normal(mu ,sigma, size)
print(normals)
# Out:
# [4.14972724 3.67006122 4.88803013 4.97653995 4.74372389 6.17131781
#  6.47349717 6.60239777 5.73752523 6.46938007 4.46209318 5.23783396
#  6.1465403  4.81622469 4.95814575 3.43599931 6.4345683  5.57613452
#  5.30810985 4.51394375 4.15784007 5.79121699 4.18577948 5.28409678
#  6.00644581 4.49114072 5.48887569 4.88203606 4.66833529 5.32228381
#  5.24874969 4.93581999 5.35263384 5.68025876 6.58207689 5.77990042]

# %%
age:当初は２次元扱いの中で１行という扱いになっていた
# Out:
# array([[67, 69, 84, 44, 50, 87, 89, 60, 78, 40, 75, 51, 68, 57, 49, 70,
#         52, 63, 87, 50, 73, 69, 56, 51, 69, 69, 80, 44, 79, 54, 68, 46,
#         43, 86, 67, 62, 68, 42, 85, 40, 83, 66, 57, 55, 46, 51, 58, 82,
#         52, 68, 47, 82, 78, 85, 71, 54, 64, 63, 76, 58, 74, 80, 70, 48,
#         55, 65, 83, 79, 78, 40, 83, 76, 45, 88, 85, 48, 74, 49, 54, 72,
#         86, 70, 54, 52, 67, 57, 60, 61, 45, 65, 42, 87, 64, 66, 45, 64,
#         85, 60, 72, 41]])

# %%
sex
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'F', 'M', 'F', 'F',
#        'F', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'M', 'F', 'F', 'M', 'M',
#        'M', 'F', 'M', 'F', 'F', 'F', 'F', 'F', 'F', 'M', 'M', 'F', 'F',
#        'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'M', 'M',
#        'F', 'M', 'M', 'M', 'F', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'F',
#        'M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'M', 'F', 'F',
#        'F', 'F', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'F', 'M', 'F',
#        'F', 'F', 'F', 'M', 'F', 'M', 'F', 'F', 'F'], dtype='<U1')

# %%
age
# Out:
# array([77, 58, 56, 65, 74, 50, 50, 64, 62, 81, 75, 43, 50, 46, 66, 46, 64,
#        56, 44, 87, 41, 54, 49, 40, 88, 63, 74, 66, 69, 77, 56, 43, 87, 47,
#        60, 54, 81, 56, 55, 69, 83, 41, 80, 52, 77, 69, 79, 59, 67, 57, 82,
#        52, 86, 41, 67, 47, 59, 62, 58, 50, 44, 54, 77, 42, 47, 45, 42, 85,
#        89, 70, 61, 75, 84, 43, 54, 65, 54, 77, 84, 52, 42, 53, 65, 69, 76,
#        87, 73, 89, 71, 64, 44, 79, 80, 41, 83, 48, 66, 41, 75, 75])
